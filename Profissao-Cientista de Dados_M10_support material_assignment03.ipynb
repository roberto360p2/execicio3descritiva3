# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# # Indice <a name = "Voltar"></a>
#
# 1. [Importando o pacotes](#1)
# 2. [Importando a base de dados](#2)
# 3. [Exercicio 1](#3)
# 4. [Exercicio 2](#4)

# %% [markdown]
# # <font color = "Green"> **1 Importando os pacotes** <a name = "1"></a>
#
# [Voltar ao Indice](#Voltar)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# # <font color = "Green"> **2 Importando a base de dados** <a name = "2"></a>
#
# [Voltar ao Indice](#Voltar)

# %%
base = pd.read_csv(r"C:\Users\Positivo\Desktop\Cursos\Curso Ciencias de dados Ebac\Ciencias de dados\Modulo10descritiva2\Aula1\Profissao- Cientista de Dados_M10_support material.csv")
base = base.drop("Unnamed: 0",axis=1)
base.head()
# Out:
#      data_ref  index sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0  2015-01-01   8682    F             False             True           1
# 1  2015-01-01  12830    M              True             True           0
# 2  2015-01-01   2885    M              True             True           2
# 3  2015-01-01  16168    F              True            False           0
# 4  2015-01-01  12438    M             False            False           0
#
#     tipo_renda           educacao estado_civil tipo_residencia  idade  \
# 0  Assalariado         Secundário       Casado            Casa     36
# 1   Empresário         Secundário       Casado            Casa     42
# 2  Assalariado  Superior completo       Casado            Casa     31
# 3   Empresário         Secundário       Casado            Casa     50
# 4  Assalariado         Secundário       Casado            Casa     52
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %% [markdown]
# # <font color = "Green"> **3 Exercicio 1** <a name = "3"></a>
#
# [Voltar ao Indice](#Voltar)

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
base["data_ref"] = pd.to_datetime(base["data_ref"])
base.set_index("data_ref",inplace=True)
base["mes"] = base.index.month
base["ano"] = base.index.year

# %%
base[base["ano"]==2015].groupby(["mes"])["renda"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='mes'>

# %%
base[base["ano"]==2016].groupby(["mes"])["renda"].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='mes'>

# %%
from numpy import mean
plt.figure(figsize=[15,5])
sns.barplot(x="mes",y="renda",data=base,hue="sexo",estimator=mean)
# Out:
# <AxesSubplot:xlabel='mes', ylabel='renda'>

# %% [markdown]
# - Confome podemos ver na renda media ao longo do tempo cadastrdo temos uma difrença entre os sexo F e M

# %% [markdown]
# # <font color = "Green"> **4 Exercicio 2** <a name = "4"></a>
#
# [Voltar ao Indice](#Voltar)

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
from numpy import mean
sns.barplot(x="mes",y="renda",data=base,hue="posse_de_veiculo",estimator=mean)
# Out:
# <AxesSubplot:xlabel='mes', ylabel='renda'>

# %%
from numpy import mean
plt.figure(figsize=[15,5])
sns.barplot(x="mes",y="renda",data=base,hue="posse_de_imovel",estimator=mean)
# Out:
# <AxesSubplot:xlabel='mes', ylabel='renda'>

# %%
from numpy import mean
plt.figure(figsize=[15,5])
sns.barplot(x="tipo_renda",y="renda",data=base,hue="sexo",estimator=mean)
# Out:
# <AxesSubplot:xlabel='tipo_renda', ylabel='renda'>

# %%
from numpy import mean
plt.figure(figsize=[15,7])
sns.barplot(x="mes",y="renda",data=base,hue="educacao",estimator=mean)
# Out:
# <AxesSubplot:xlabel='mes', ylabel='renda'>

# %%
from numpy import mean
plt.figure(figsize=[15,7])
sns.(x="mes",y="renda",data=base,hue="educacao",estimator=mean)

# %%
plt.figure(figsize=[15,7])
sns.regplot(x="renda",y="tempo_emprego",data=base)
# Out:
# <AxesSubplot:xlabel='renda', ylabel='tempo_emprego'>
